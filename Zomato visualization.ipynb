# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('zomato.csv')

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
#                          cuisines avg_cost menu_item meal_type          city
# 0  North Indian, Mughlai, Chinese      800        []    Buffet  Banashankari
# 1     Chinese, North Indian, Thai      800        []    Buffet  Banashankari
# 2          Cafe, Mexican, Italian      800        []    Buffet  Banashankari
# 3      South Indian, North Indian      300        []    Buffet  Banashankari
# 4        North Indian, Rajasthani      600        []    Buffet  Banashankari

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.drop(columns=['url','phone','address','reviews_list'],inplace=True)

# %%
data.isnull().sum()
# Out:
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'dish_liked', 'cuisines', 'approx_cost(for two people)',
#        'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.rate
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 51717, dtype: object

# %%
#data['rate'].value_counts()
data['rate'].isnull().sum()
# Out:
# 7775

# %%
data=data.rename(columns={"approx_cost(for two people)":"avg_cost","listed_in(type)":"meal_type","listed_in(city)" : "city"})

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'dish_liked', 'cuisines', 'avg_cost', 'menu_item',
#        'meal_type', 'city'],
#       dtype='object')

# %%
data.name.value_counts()
# Out:
# Cafe Coffee Day                           96
# Onesta                                    85
# Just Bake                                 73
# Empire Restaurant                         71
# Five Star Chicken                         70
#                                           ..
# Art Of Flavours                            1
# A1 Ambur Dum Biryani And Parota Centre     1
# Luo Han                                    1
# SaJuSo                                     1
# Shake it Off                               1
# Name: name, Length: 8792, dtype: int64

# %%
data.online_order.value_counts()
# Out:
# Yes    30444
# No     21273
# Name: online_order, dtype: int64

# %%
data.book_table.value_counts()
# Out:
# No     45268
# Yes     6449
# Name: book_table, dtype: int64

# %%
data.rate.value_counts()
# Out:
# NEW       2208
# 3.9/5     2098
# 3.8/5     2022
# 3.7/5     2011
# 3.9 /5    1874
#           ...
# 2.0 /5       7
# 2.2 /5       7
# 2.0/5        4
# 1.8 /5       3
# 1.8/5        2
# Name: rate, Length: 64, dtype: int64

# %%
data.votes.value_counts()
# Out:
# 0       10027
# 4        1140
# 6         992
# 7         872
# 9         738
#         ...
# 1735        1
# 1590        1
# 1351        1
# 3334        1
# 2353        1
# Name: votes, Length: 2328, dtype: int64

# %%
data.location.value_counts()
# Out:
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: location, Length: 93, dtype: int64

# %%
data.rest_type.value_counts()
# Out:
# Quick Bites                   19132
# Casual Dining                 10330
# Cafe                           3732
# Delivery                       2604
# Dessert Parlor                 2263
#                               ...
# Bakery, Food Court                2
# Dessert Parlor, Kiosk             2
# Cafe, Food Court                  2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: rest_type, Length: 93, dtype: int64

# %%
data.dish_liked.value_counts()
# Out:
# Biryani                                                                                                           182
# Chicken Biryani                                                                                                    73
# Friendly Staff                                                                                                     69
# Waffles                                                                                                            68
# Paratha                                                                                                            57
#                                                                                                                  ...
# Chicken Sizzler, Brownie, Sea Food, Veg Shashlik, Steak, Veg Sizzler, Custard                                       1
# Sandwiches, Oreo Shake, Burgers                                                                                     1
# Sea Food, Prawn Ghee Roast, Fish Curry, Murgh Ghee Roast, Neer Dosa, Biryani, Chicken Thali                         1
# Vada, Masala Idli, Benne Khali Dosa, Benne Masala Dosa, Set Dosa, Filter Coffee                                     1
# Palak Chicken, Mutton Keema Masala, Sarson Ka Saag, Mushroom Masala, Makkai Roti, Palak Paneer, Butter Chicken      1
# Name: dish_liked, Length: 5271, dtype: int64

# %%
data.avg_cost.value_counts()
# Out:
# 300      7576
# 400      6562
# 500      4980
# 200      4857
# 600      3714
#          ...
# 5,000       1
# 60          1
# 3,700       1
# 160         1
# 560         1
# Name: avg_cost, Length: 70, dtype: int64

# %%
data.meal_type.value_counts()
# Out:
# Delivery              25942
# Dine-out              17779
# Desserts               3593
# Cafes                  1723
# Drinks & nightlife     1101
# Buffet                  882
# Pubs and bars           697
# Name: meal_type, dtype: int64

# %%
data.drop(columns=['location'],inplace=True,axis=1)

# %%
data.isnull().sum()
# Out:
# name                0
# online_order        0
# book_table          0
# rate             7775
# votes               0
# rest_type         227
# dish_liked      28078
# cuisines           45
# avg_cost          346
# menu_item           0
# meal_type           0
# city                0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context("paper",font_scale=2,rc={"font-size":20,"axes.titlesize":25,"axes.labelsize": 20})
sns.catplot(data=data,kind='count',x='online_order')
plt.title("Number of resturants that take order online")
plt.show()

# %%
sns.set_context("paper",font_scale=2,rc={"font-size":20,"axes.titlesize":25,"axes.labelsize": 20})
sns.catplot(data=data,kind='count',x='book_table')
plt.title("Number of resturants that have option to book table online")
plt.show()

# %%
sns.set_context("paper",font_scale=1,rc={"font-size":3,"axes.titlesize":3,"axes.labelsize": 3})
sns.catplot(data=data,kind="count",x="meal_type")
plt.title("No. of resturants according to meal type")
plt.show()

# %%
sns.set_context("paper", font_scale = 1, rc={"font.size": 3,"axes.titlesize": 5,"axes.labelsize": 2})   
b = sns.catplot(data = data, kind = 'count', x = 'city')
plt.title('Number of restaurants in each city')
b.set_xticklabels(rotation = 90)
plt.show()

# %%
sns.set_context("paper",font_scale=1,rc={"font.size": 20,"axes.titlesize": 25,"axes.labelsize": 20})
b=sns.catplot(data=data,kind='count',x='rate',order=data['rate'].value_counts().index)
plt.title("Number of restuarants for each rating")
b.set_xticklabels(rotation=90)
plt.show()

# %%
# Plotting count plot of rest_type
plt.figure(figsize=(50,15))
sns.set_context("paper", font_scale = 1, rc = {"font.size": 5,"axes.titlesize": 25,"axes.labelsize": 2})   
b = sns.catplot(data = data, kind = 'count', x = 'rest_type', order = data['rest_type'].value_counts().index)
plt.title('Number of restaurants for each type')
b.set_xticklabels(rotation = 90)
plt.show()

# count plot of top 10
sns.set_context("paper", font_scale = 1, rc = {"font.size": 20,"axes.titlesize": 25,"axes.labelsize": 20})   
b = sns.catplot(data = data, kind = 'count', x = 'rest_type', order = data['rest_type'].value_counts().head(10).index)
plt.title('Number of restaurants for each type')
b.set_xticklabels(rotation = 90)
plt.show()

# count plot of type last 10
sns.set_context("paper", font_scale = 1, rc = {"font.size": 20,"axes.titlesize": 25,"axes.labelsize": 20})   
b = sns.catplot(data = data, kind = 'count', x = 'rest_type', order = data['rest_type'].value_counts().tail(10).index)
plt.title('Number of restaurants for each type')
b.set_xticklabels(rotation = 90)
plt.show()

# %%
sns.set_context("paper", font_scale = 1, rc = {"font.size": 20,"axes.titlesize": 25,"axes.labelsize": 20})   
b = sns.catplot(data = data, kind = 'count', x = 'avg_cost', order = data['avg_cost'].value_counts().tail(10).index)
plt.title('Number of restaurants for each type')
b.set_xticklabels(rotation = 90)
plt.show()

# %%
dishes_data = data[data.dish_liked.notnull()]
dishes_data.dish_liked = dishes_data.dish_liked.apply(lambda x:x.lower().strip())
dishes_data.isnull().sum()
dishes_count=[]
for i in dishes_data.dish_liked:
    for t in i.split(','):
        t=t.strip()
        dishes_count.append(t)

# %%
plt.figure(figsize=(12,8))
pd.Series(dishes_count).value_counts()[:20].plot(kind='bar',color='c')
plt.title("most 20 liked dishes in banglore",weight='bold')
plt.show()
