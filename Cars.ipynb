# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("cars.csv")
data.head(10)
# Out:
#                        Model   MPG  Cylinders  Displacement  Horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
# 5           ford galaxie 500  15.0          8           NaN       198.0
# 6           chevrolet impala  14.0          8         454.0       220.0
# 7          plymouth fury iii  14.0          8         440.0       215.0
# 8           pontiac catalina  14.0          8         455.0       225.0
# 9         amc ambassador dpl  15.0          8         390.0       190.0
#
#    Weight  Acceleration  Year Origin
# 0  3504.0          12.0    70     US
# 1  3693.0          11.5    70     US
# 2  3436.0          11.0    70    USA
# ...

# %%
data['Origin'].unique()
# Out:
# array(['US', 'USA', 'Japan', 'Europe', 'France', nan], dtype=object)

# %%
dit={'US': '100001', 'USA':'100001', 'Japan':'100010', 'Europe':'100100', 'France':'101000'}

# %%
data['transformed']=data['Origin'].map(dit)

# %%
data
# Out:
#                          Model   MPG  Cylinders  Displacement  Horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 389            ford mustang gl  27.0          4         140.0        86.0
# 390                  vw pickup  44.0          4          97.0        52.0
# 391              dodge rampage  32.0          4         135.0        84.0
# 392                ford ranger  28.0          4         120.0        79.0
# 393                 chevy s-10  31.0          4         119.0        82.0
#
#      Weight  Acceleration  Year  Origin transformed
# ...
